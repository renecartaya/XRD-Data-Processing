# %%
#####################################################################################################################################
##                                                                                                                                 ##
##                                                                                                                                 ## 
##                                                    Package loading                                                              ##
##                                                                                                                                 ##
##                                                                                                                                 ##
##                                                                                                                                 ##   
#####################################################################################################################################
from scipy import signal
import numpy as np
import pandas as pd
import math as m
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import norm
#from matplotlib import pyplot as plt

# %%
#####################################################################################################
#
#                                                 Directorio
#
#####################################################################################################

directorio_in = 'C:/Users/renea/Desktop/Data XRD/'
directorio_out = 'C:/Users/renea/Desktop/Data XRD/'

# %%
raw_data = open("C:/Users/renea/Desktop/Data XRD/xrd_sample.raw", "rb")

# %%
txt_data = pd.read_csv("C:/Users/renea/Desktop/Data XRD/xrd_sample.txt", sep='\t',header = 2)
txt_data
# Out:
#       17.65946  117.00
# 0     17.58915   114.0
# 1     17.51940   101.0
# 2     17.45020    82.0
# 3     17.38154   124.0
# 4     17.31342   107.0
# ...        ...     ...
# 2745   1.54246   205.0
# 2746   1.54199   182.0
# 2747   1.54152   176.0
# 2748   1.54106   191.0
# 2749   1.54059   174.0
#
# [2750 rows x 2 columns]

# %%
txt_data = txt_data.to_numpy()
txt_data
# Out:
# array([[ 17.58915, 114.     ],
#        [ 17.5194 , 101.     ],
#        [ 17.4502 ,  82.     ],
#        ...,
#        [  1.54152, 176.     ],
#        [  1.54106, 191.     ],
#        [  1.54059, 174.     ]])

# %%
x = DataXRD[0:,0]
x
# Out:
# array([17.58915, 17.5194 , 17.4502 , ...,  1.54152,  1.54106,  1.54059])

# %%
y = DataXRD[0:,1]
y
# Out:
# array([114., 101.,  82., ..., 176., 191., 174.])

# %%
directory_in = "C:/Users/renea/Desktop/Data XRD/"
data_in = "xrd_sample.txt"

source = directory_in + data_in

Image_save = data_in.replace('txt','png')
plot_out = directorio_out + Image_save

DataXRD = pd.read_csv(source, sep='\t',header = 2)
DataXRD = DataXRD.to_numpy()
DataXRD[0:,0:]

x = DataXRD[0:,0]
y = DataXRD[0:,1]

plt.plot(x,y, linewidth=2, color = 'royalblue')

plt.title('XRD plot model',  fontsize = 22)
plt.xticks(fontsize=18, rotation=0)
plt.yticks(fontsize=18, rotation=0)
plt.xlabel("2$\u03B8$ (degree)", color = "black", family = "Serif", fontsize = 18)
plt.ylabel("Intensity (a.u.)", color = "black", family = "Serif", fontsize = 18)

plt.rcParams["figure.figsize"] = (15,15)

plt.savefig(plot_out, dpi=350)

# %%
directory_in = "C:/Users/renea/Desktop/Data XRD/"
data_in = "xrd_sample.txt"

source = directory_in + data_in

Image_save = data_in.replace('txt','png')
plot_out = directorio_out + Image_save

DataXRD = pd.read_csv(source, sep='\t',header = 2)
DataXRD = DataXRD.to_numpy()
DataXRD[0:,0:]

x = DataXRD[0:,0]
y = DataXRD[0:,1]

plt.scatter(x,y, linewidth=2, color = 'royalblue')

plt.title('XRD plot model',  fontsize = 22)
plt.xticks(fontsize=18, rotation=0)
plt.yticks(fontsize=18, rotation=0)
plt.xlabel("2$\u03B8$ (degree)", color = "black", family = "Serif", fontsize = 18)
plt.ylabel("Intensity (a.u.)", color = "black", family = "Serif", fontsize = 18)

plt.rcParams["figure.figsize"] = (15,15)

plt.savefig(plot_out, dpi=350)
